# %%
#Import Lib
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob

from textblob import TextBlob
import csv 

#create object
def sentiment(polarity):
    if blob.sentiment.polarity < 0:
        print("Negative")
    elif blob.sentiment.polarity > 0:
        print("Positive")
    else:
        print("Neutral")

infile = 'NYtimes.csv'

with open(infile, 'r', encoding="utf8") as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        sentence = row[0]
        blob = TextBlob(sentence)
        print(blob.sentiment)
        sentiment(blob.sentiment.polarity)
# Out:
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.022222222222222213, subjectivity=0.24444444444444446)
# Positive
# Sentiment(polarity=-0.15555555555555559, subjectivity=0.2888888888888889)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.06666666666666667)
# Neutral
# Sentiment(polarity=-0.7, subjectivity=0.9)
# Negative
# Sentiment(polarity=0.2, subjectivity=0.1)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=-0.2, subjectivity=0.6)
# Negative
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.1, subjectivity=0.4)
# Positive
# Sentiment(polarity=0.35, subjectivity=0.44999999999999996)
# Positive
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.0, subjectivity=0.0)
# Neutral
# Sentiment(polarity=0.4, subjectivity=0.5)
# Positive
# Sentiment(polarity=0.4, subjectivity=1.0)
# Positive
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline  
import nltk
from nltk import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import LancasterStemmer, WordNetLemmatizer, PorterStemmer
from wordcloud import WordCloud, STOPWORDS
from textblob import TextBlob

from textblob import TextBlob
import csv 
import csv
from textblob import TextBlob

def sentiment(polarity):
    if blob.sentiment.polarity < 0:
        print("Negative")
    elif blob.sentiment.polarity > 0:
        print("Positive")
    else:
        print("Neutral")
        
infile = 'NYtimes.csv'
data =[]
state = []
with open(infile, 'r', encoding="utf8") as csvfile:
    rows = csv.reader(csvfile)
    for row in rows:
        sentence = row[0]
        blob = TextBlob(sentence)
        NYTpolarity = blob.sentiment.polarity
        NYTsubjectivity = blob.sentiment.subjectivity
        data.append([NYTpolarity,NYTsubjectivity])

# %%
import pandas as pd
df = pd.DataFrame(data,columns=['NYTpolarity','NYTsubjectivity'])

# %%
df.head()
# Out:
#    NYTpolarity  NYTsubjectivity
# 0     0.000000         0.000000
# 1     0.022222         0.244444
# 2    -0.155556         0.288889
# 3     0.000000         0.066667
# 4    -0.700000         0.900000

# %%
df.to_csv('NYTdataSentiment.csv',index=False, encoding = 'utf-8')
